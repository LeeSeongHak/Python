# %% [markdown]
# ### 간단한 linear regression 테스트

# %%
import tensorflow as tf

# %%
x = [1, 2, 3] # feature
y = [1, 2, 3] # label

# %%
w = tf.Variable(tf.random_normal([1]), name="weight") # Variable은 반드시 initializer를 해줘야함.
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
hypothesis = x * w + b # 수학식과 다르게 tensorflow에서는 x를 먼저 씀.

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y))

# %%
learning_rate = 0.01

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = learning_rate)

# %%
train = optimizer.minimize(cost)
# 한줄로 하고 싶을 때 : train = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)

# %%
with tf.Session() as sess :
    sess.run(tf.global_variables_initializer())
    
    for step in range(3000) :
        _, cost_val, w_val, b_val = sess.run([train, cost, w, b]) # train은 출력해도 none이 오기 때문에 _로 변수 적어서 안받음.
        
        if step % 20 == 0 :
            print(step, cost_val, w_val, b_val)
# Out:
# 0 21.30949 [-0.20424516] [-1.5789924]
# 20 0.2933776 [1.2170608] [-0.90444684]
# 40 0.093636274 [1.3368067] [-0.8047773]
# 60 0.083475135 [1.3333513] [-0.76151264]
# 80 0.07579921 [1.3188633] [-0.7252061]
# 100 0.0688419 [1.3039901] [-0.6910746]
# 120 0.06252331 [1.2897143] [-0.658592]
# 140 0.056784686 [1.2760998] [-0.62764007]
# 160 0.05157276 [1.2631242] [-0.59814316]
# 180 0.046839166 [1.2507584] [-0.5700326]
# 200 0.042540103 [1.2389736] [-0.5432433]
# 220 0.038635623 [1.2277428] [-0.5177128]
# 240 0.03508946 [1.2170397] [-0.49338207]
# 260 0.03186882 [1.2068397] [-0.47019503]
# 280 0.02894379 [1.1971189] [-0.44809768]
# 300 0.0262872 [1.1878551] [-0.4270388]
# 320 0.023874454 [1.1790266] [-0.40696952]
# 340 0.02168317 [1.170613] [-0.38784343]
# 360 0.019692989 [1.1625947] [-0.36961624]
# 380 0.01788549 [1.1549534] [-0.35224557]
# 400 0.016243916 [1.1476712] [-0.33569133]
# 420 0.014752972 [1.1407312] [-0.31991515]
# 440 0.013398879 [1.1341172] [-0.3048803]
# 460 0.012169078 [1.1278143] [-0.290552]
# 480 0.011052144 [1.1218077] [-0.27689716]
# 500 0.010037761 [1.116083] [-0.26388413]
# 520 0.0091164475 [1.1106277] [-0.25148258]
# 540 0.008279709 [1.1054286] [-0.23966381]
# 560 0.007519757 [1.1004736] [-0.22840048]
# 580 0.0068295714 [1.0957518] [-0.21766649]
# 600 0.006202728 [1.0912519] [-0.20743695]
# 620 0.0056334175 [1.0869634] [-0.1976882]
# 640 0.0051163575 [1.0828766] [-0.18839763]
# 660 0.0046467646 [1.0789815] [-0.17954369]
# 680 0.0042202636 [1.0752697] [-0.17110576]
# 700 0.0038329083 [1.0717323] [-0.16306442]
# 720 0.003481101 [1.068361] [-0.15540095]
# 740 0.003161601 [1.0651485] [-0.14809768]
# 760 0.0028714163 [1.0620869] [-0.14113769]
# 780 0.0026078674 [1.0591688] [-0.13450487]
# 800 0.0023685042 [1.0563881] [-0.12818362]
# 820 0.0021511114 [1.0537382] [-0.12215946]
# 840 0.0019536775 [1.0512127] [-0.11641841]
# 860 0.0017743603 [1.0488058] [-0.11094718]
# 880 0.0016115123 [1.0465122] [-0.1057331]
# 900 0.0014635936 [1.0443263] [-0.10076406]
# 920 0.0013292612 [1.0422432] [-0.09602855]
# 940 0.0012072503 [1.0402576] [-0.09151548]
# 960 0.0010964454 [1.0383657] [-0.08721446]
# 980 0.0009958105 [1.0365627] [-0.08311564]
# 1000 0.0009044083 [1.0348444] [-0.07920948]
# 1020 0.0008213953 [1.0332068] [-0.07548687]
# 1040 0.00074600725 [1.0316463] [-0.07193927]
# 1060 0.00067753484 [1.0301589] [-0.06855839]
# 1080 0.0006153454 [1.0287416] [-0.06533635]
# 1100 0.0005588696 [1.0273908] [-0.06226578]
# 1120 0.0005075754 [1.0261036] [-0.05933956]
# 1140 0.00046098806 [1.0248768] [-0.05655086]
# 1160 0.00041867656 [1.0237077] [-0.05389321]
# 1180 0.00038024798 [1.0225936] [-0.05136048]
# 1200 0.0003453502 [1.0215319] [-0.04894676]
# 1220 0.00031365335 [1.0205199] [-0.04664656]
# 1240 0.00028486206 [1.0195554] [-0.04445422]
# 1260 0.00025871667 [1.0186363] [-0.042365]
# 1280 0.00023497024 [1.0177605] [-0.04037395]
# 1300 0.00021340324 [1.0169259] [-0.03847654]
# 1320 0.00019381563 [1.0161304] [-0.03666829]
# 1340 0.00017602724 [1.0153724] [-0.03494499]
# 1360 0.00015987073 [1.0146499] [-0.03330269]
# 1380 0.00014519643 [1.0139614] [-0.03173759]
# 1400 0.00013187018 [1.0133052] [-0.03024602]
# 1420 0.00011976567 [1.0126799] [-0.02882454]
# 1440 0.000108774075 [1.0120841] [-0.02746989]
# 1460 9.879042e-05 [1.0115162] [-0.02617892]
# 1480 8.972284e-05 [1.010975] [-0.02494865]
# 1500 8.148796e-05 [1.0104593] [-0.02377617]
# 1520 7.4009804e-05 [1.0099677] [-0.02265885]
# 1540 6.721623e-05 [1.0094992] [-0.02159391]
# 1560 6.104554e-05 [1.0090528] [-0.02057903]
# 1580 5.5444212e-05 [1.0086273] [-0.01961188]
# 1600 5.035472e-05 [1.0082219] [-0.01869019]
# 1620 4.5732584e-05 [1.0078355] [-0.01781184]
# 1640 4.1535077e-05 [1.0074673] [-0.01697479]
# 1660 3.77223e-05 [1.0071162] [-0.016177]
# 1680 3.42605e-05 [1.0067819] [-0.0154168]
# 1700 3.1115993e-05 [1.006463] [-0.01469227]
# 1720 2.826038e-05 [1.0061593] [-0.01400175]
# 1740 2.5666019e-05 [1.0058699] [-0.01334367]
# 1760 2.3310467e-05 [1.0055941] [-0.01271661]
# 1780 2.1171641e-05 [1.0053312] [-0.01211901]
# 1800 1.922765e-05 [1.0050807] [-0.01154947]
# 1820 1.7463004e-05 [1.0048418] [-0.01100668]
# 1840 1.5860394e-05 [1.0046144] [-0.01048939]
# 1860 1.4404705e-05 [1.0043974] [-0.00999643]
# 1880 1.3081986e-05 [1.0041907] [-0.0095266]
# 1900 1.1881781e-05 [1.0039939] [-0.00907889]
# 1920 1.0791085e-05 [1.0038061] [-0.00865222]
# 1940 9.800725e-06 [1.0036273] [-0.00824558]
# 1960 8.9010655e-06 [1.0034568] [-0.00785811]
# 1980 8.084298e-06 [1.0032942] [-0.00748879]
# 2000 7.3419674e-06 [1.0031395] [-0.00713683]
# 2020 6.6680627e-06 [1.002992] [-0.00680145]
# 2040 6.0567113e-06 [1.0028514] [-0.00648187]
# 2060 5.500367e-06 [1.0027175] [-0.00617729]
# 2080 4.995757e-06 [1.0025897] [-0.00588698]
# 2100 4.5373463e-06 [1.0024681] [-0.00561035]
# 2120 4.1207836e-06 [1.002352] [-0.00534673]
# 2140 3.7429545e-06 [1.0022416] [-0.00509547]
# 2160 3.3991325e-06 [1.0021362] [-0.00485606]
# 2180 3.0872764e-06 [1.0020359] [-0.00462785]
# 2200 2.8038137e-06 [1.0019403] [-0.00441038]
# 2220 2.5465724e-06 [1.001849] [-0.00420317]
# 2240 2.3129503e-06 [1.0017622] [-0.00400572]
# 2260 2.100808e-06 [1.0016794] [-0.00381751]
# 2280 1.9080042e-06 [1.0016005] [-0.00363812]
# 2300 1.7328426e-06 [1.0015254] [-0.00346724]
# 2320 1.5738639e-06 [1.0014536] [-0.00330436]
# 2340 1.4295878e-06 [1.0013856] [-0.00314916]
# 2360 1.2983123e-06 [1.0013204] [-0.00300128]
# 2380 1.1794384e-06 [1.0012584] [-0.00286034]
# 2400 1.0713467e-06 [1.0011994] [-0.00272603]
# 2420 9.73055e-07 [1.0011431] [-0.00259803]
# 2440 8.8390493e-07 [1.0010895] [-0.00247605]
# 2460 8.0264243e-07 [1.0010383] [-0.0023598]
# 2480 7.2917675e-07 [1.0009896] [-0.002249]
# 2500 6.622383e-07 [1.0009432] [-0.00214343]
# 2520 6.015385e-07 [1.0008988] [-0.0020428]
# 2540 5.464078e-07 [1.0008566] [-0.00194688]
# 2560 4.9629483e-07 [1.0008162] [-0.00185553]
# 2580 4.508648e-07 [1.0007781] [-0.00176848]
# 2600 4.096435e-07 [1.0007417] [-0.00168548]
# 2620 3.7198288e-07 [1.0007069] [-0.00160636]
# 2640 3.3794572e-07 [1.0006735] [-0.00153108]
# 2660 3.069998e-07 [1.0006422] [-0.00145924]
# 2680 2.7886307e-07 [1.0006119] [-0.00139073]
# 2700 2.5337383e-07 [1.0005833] [-0.00132558]
# 2720 2.3002274e-07 [1.000556] [-0.00126335]
# 2740 2.089842e-07 [1.0005298] [-0.00120417]
# 2760 1.8988618e-07 [1.0005052] [-0.00114764]
# 2780 1.7255921e-07 [1.0004814] [-0.00109396]
# 2800 1.5672187e-07 [1.000459] [-0.00104259]
# 2820 1.4242461e-07 [1.0004374] [-0.00099382]
# 2840 1.2930855e-07 [1.0004168] [-0.00094712]
# 2860 1.1749859e-07 [1.0003976] [-0.00090283]
# 2880 1.06738234e-07 [1.0003785] [-0.00086057]
# 2900 9.699088e-08 [1.000361] [-0.00082015]
# 2920 8.813324e-08 [1.0003443] [-0.00078186]
# 2940 8.002687e-08 [1.0003277] [-0.0007452]
# 2960 7.2743e-08 [1.0003126] [-0.00071021]
# 2980 6.610245e-08 [1.0002983] [-0.00067709]
